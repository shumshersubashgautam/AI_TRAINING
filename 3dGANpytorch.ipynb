# %% [markdown]
# <a href="https://colab.research.google.com/github/shumshersubashgautam/AI_TRAINING/blob/master/3dGANpytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Prinsphield/3D-GAN-pytorch.git
# Out:
# Cloning into '3D-GAN-pytorch'...
# remote: Enumerating objects: 40, done.
# remote: Total 40 (delta 0), reused 0 (delta 0), pack-reused 40
# Unpacking objects: 100% (40/40), done.

# %%
cd /content/3D-GAN-pytorch
# Out:
# /content/3D-GAN-pytorch

# %%
# !wget http://3dshapenets.cs.princeton.edu/3DShapeNetsCode.zip
# Out:
# --2020-04-27 15:51:33--  http://3dshapenets.cs.princeton.edu/3DShapeNetsCode.zip
# Resolving 3dshapenets.cs.princeton.edu (3dshapenets.cs.princeton.edu)... 128.112.136.51
# Connecting to 3dshapenets.cs.princeton.edu (3dshapenets.cs.princeton.edu)|128.112.136.51|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 533450062 (509M) [application/zip]
# Saving to: ‘3DShapeNetsCode.zip’
#
# 3DShapeNetsCode.zip 100%[===================>] 508.74M  16.6MB/s    in 32s
#
# 2020-04-27 15:52:06 (15.8 MB/s) - ‘3DShapeNetsCode.zip’ saved [533450062/533450062]

# %%
# !unzip 3DShapeNetsCode.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e27f30e2e64a38a55df01c2136057bf7_9.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e27f30e2e64a38a55df01c2136057bf7_2.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e27f30e2e64a38a55df01c2136057bf7_1.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e26c5b80af944428873ec74c119307b9_3.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e26c5b80af944428873ec74c119307b9_10.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e26c5b80af944428873ec74c119307b9_1.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e2116e0b34db656dfca1f1143bb6bc17_8.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e2116e0b34db656dfca1f1143bb6bc17_1.mat
#   inflating: 3DShapeNets/volumetric_data/airplane/30/train/e1fbbf2ea1989b49fb2ad20449a93a60_4.mat
# ...

# %%
# !mv 3DShapeNets ModelNet

# %%
import os
import scipy.ndimage as nd
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %matplotlib notebook


# import skimage.measure as sk

def plotFromVoxels(voxels):
    z,x,y = voxels.nonzero()
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x, y, -z, zdir='z', c= 'red')
    plt.show()

def getVoxelFromMat(path, cube_len=64):
    voxels = io.loadmat(path)['instance']
    voxels = np.pad(voxels,(1,1),'constant',constant_values=(0,0))
    if cube_len != 32 and cube_len == 64:
        voxels = nd.zoom(voxels, (2,2,2), mode='constant', order=0)
    return voxels

filename = '/content/3D-GAN-pytorch/ModelNet/3DShapeNets/volumetric_data/airplane/30/test/fecbd7475115dc85237c15a579990af3_9.mat'
voxels = getVoxelFromMat(filename)

# plotFromVoxels(voxels)
print(voxels.shape)

# filename = 'train_log/img/002000_04.mat'
# f = io.loadmat(filename)
# print(f)
# # print(f['instance'].shape)


save_file = 'save.mat'
io.savemat(save_file, {'instance': voxels})
# Out:
# (64, 64, 64)

# %%
filename = 'save.mat'
voxels = getVoxelFromMat(filename)
print(voxels.shape)
plotFromVoxels(voxels)
# Out:
# (132, 132, 132)
# <div id='fc485308-618a-420f-a309-94aaf55a9377'></div>

# %%
# !pip install ipython

# %%
# !python 3dgan.py -a airplane
# Out:
# Namespace(attribute='airplane', gpu=[], mode='train', restore=None)
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# ...

# %%
# !pip install tensorboardx
# Out:
# ...
#      |████████████████████████████████| 204kB 2.8MB/s
# ...
